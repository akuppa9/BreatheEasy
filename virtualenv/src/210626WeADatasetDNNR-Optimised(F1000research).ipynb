# %% [markdown]
# # Optimised Deep Neural Network model to Predict Asthma Exacerbation based on Personalised Weather Triggers

# %%
# import required libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=DeprecationWarning)

# %%
# read the csv file 

Data = pd.read_csv('210526WeAdatasetRegression.csv')

# %% [markdown]
# # Exploratory Data Analysis

# %%
# show the dataset

Data
# Out:
#       UserNo.                        UserID      Location       Age Gender  \
# 0           1  5QBEe959GPOxv3rDNYXZXCEBOfB2      Petaling  Above 50   Male
# 1           1  5QBEe959GPOxv3rDNYXZXCEBOfB2      Petaling  Above 50   Male
# 2           1  5QBEe959GPOxv3rDNYXZXCEBOfB2      Petaling  Above 50   Male
# 3           1  5QBEe959GPOxv3rDNYXZXCEBOfB2      Petaling  Above 50   Male
# 4           1  5QBEe959GPOxv3rDNYXZXCEBOfB2      Petaling  Above 50   Male
# ...       ...                           ...           ...       ...    ...
# 1005       10  b53sAlbpdKesHxsTCiTRPL9SmGx2  Kuala Lampur     31-40   Male
# 1006       10  b53sAlbpdKesHxsTCiTRPL9SmGx2  Kuala Lampur     31-40   Male
# 1007       10  b53sAlbpdKesHxsTCiTRPL9SmGx2  Kuala Lampur     31-40   Male
# 1008       10  b53sAlbpdKesHxsTCiTRPL9SmGx2  Kuala Lampur     31-40   Male
# 1009       10  b53sAlbpdKesHxsTCiTRPL9SmGx2  Kuala Lampur     31-40   Male
#
#         OutdoorJob  OutdoorActivities SmokingHabit  Humidity  Pressure  \
# 0     Occasionally   Extremely likely           No       100      1011
# 1     Occasionally   Extremely likely           No        94      1010
# 2     Occasionally   Extremely likely           No        88      1008
# 3     Occasionally   Extremely likely           No        94      1009
# 4     Occasionally   Extremely likely           No        83      1008
# ...            ...                ...          ...       ...       ...
# 1005        Rarely  Not at all likely           No        94      1010
# 1006        Rarely  Not at all likely           No        78      1011
# 1007        Rarely  Not at all likely           No        83      1010
# 1008        Rarely  Not at all likely           No        89      1008
# 1009        Rarely  Not at all likely           No        88      1009
#
#       Temperature  UVIndex  WindSpeed  ACTScore
# 0            23.9      Low        6.7        14
# 1            25.0      Low        0.8        15
# 2            23.9  Extreme        3.1        15
# 3            22.7      Low        1.1        13
# 4            24.9      Low        5.1        15
# ...           ...      ...        ...       ...
# 1005         27.0      Low        1.3        18
# 1006         25.4      Low        1.0        18
# 1007         25.6      Low        1.0        19
# 1008         29.7  Extreme        0.9        17
# 1009         25.0      Low        2.1        19
#
# [1010 rows x 14 columns]

# %%
# get some information about the dataset

Data.info()
Data.describe().transpose()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1010 entries, 0 to 1009
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   UserNo.            1010 non-null   int64
#  1   UserID             1010 non-null   object
#  2   Location           1010 non-null   object
#  3   Age                1010 non-null   object
#  4   Gender             1010 non-null   object
#  5   OutdoorJob         1010 non-null   object
#  6   OutdoorActivities  1010 non-null   object
#  7   SmokingHabit       1010 non-null   object
#  8   Humidity           1010 non-null   int64
#  9   Pressure           1010 non-null   int64
#  10  Temperature        1010 non-null   float64
#  11  UVIndex            1010 non-null   object
#  12  WindSpeed          1010 non-null   float64
#  13  ACTScore           1010 non-null   int64
# dtypes: float64(2), int64(4), object(8)
# memory usage: 110.6+ KB
#               count         mean        std     min      25%     50%     75%  \
# UserNo.      1010.0     3.932673   2.542293     1.0     3.00     3.0     6.0
# Humidity     1010.0    81.748515  13.542801    40.0    70.00    87.0    93.0
# Pressure     1010.0  1009.264356   2.114750  1003.0  1008.00  1009.0  1011.0
# Temperature  1010.0    27.610990   2.915736    21.1    25.20    27.5    30.1
# WindSpeed    1010.0     2.373069   1.569837     0.0     1.00     2.1     3.3
# ACTScore     1010.0    16.576238   4.666969     8.0    12.25    17.0    21.0
#
#                 max
# UserNo.        10.0
# Humidity      100.0
# Pressure     1014.0
# Temperature    34.5
# WindSpeed       6.7
# ACTScore       25.0

# %%
# check if there are any Null values

Data.isnull().sum()
# Out:
# UserNo.              0
# UserID               0
# Location             0
# Age                  0
# Gender               0
# OutdoorJob           0
# OutdoorActivities    0
# SmokingHabit         0
# Humidity             0
# Pressure             0
# Temperature          0
# UVIndex              0
# WindSpeed            0
# ACTScore             0
# dtype: int64

# %%
# convert categorical data

from sklearn.preprocessing import LabelEncoder

Data['Location'] = LabelEncoder().fit_transform(Data.Location)
Data['Age'] = LabelEncoder().fit_transform(Data.Age)
Data['Gender'] = LabelEncoder().fit_transform(Data.Gender)
Data['OutdoorJob'] = LabelEncoder().fit_transform(Data.OutdoorJob)
Data['OutdoorActivities'] = LabelEncoder().fit_transform(Data.OutdoorActivities)
Data['UVIndex'] = LabelEncoder().fit_transform(Data.UVIndex)

Data
# Out:
#       UserNo.                        UserID  Location  Age  Gender  \
# 0           1  5QBEe959GPOxv3rDNYXZXCEBOfB2         4    3       1
# 1           1  5QBEe959GPOxv3rDNYXZXCEBOfB2         4    3       1
# 2           1  5QBEe959GPOxv3rDNYXZXCEBOfB2         4    3       1
# 3           1  5QBEe959GPOxv3rDNYXZXCEBOfB2         4    3       1
# 4           1  5QBEe959GPOxv3rDNYXZXCEBOfB2         4    3       1
# ...       ...                           ...       ...  ...     ...
# 1005       10  b53sAlbpdKesHxsTCiTRPL9SmGx2         3    1       1
# 1006       10  b53sAlbpdKesHxsTCiTRPL9SmGx2         3    1       1
# 1007       10  b53sAlbpdKesHxsTCiTRPL9SmGx2         3    1       1
# 1008       10  b53sAlbpdKesHxsTCiTRPL9SmGx2         3    1       1
# 1009       10  b53sAlbpdKesHxsTCiTRPL9SmGx2         3    1       1
#
#       OutdoorJob  OutdoorActivities SmokingHabit  Humidity  Pressure  \
# 0              1                  0           No       100      1011
# 1              1                  0           No        94      1010
# 2              1                  0           No        88      1008
# 3              1                  0           No        94      1009
# 4              1                  0           No        83      1008
# ...          ...                ...          ...       ...       ...
# 1005           2                  2           No        94      1010
# 1006           2                  2           No        78      1011
# 1007           2                  2           No        83      1010
# 1008           2                  2           No        89      1008
# 1009           2                  2           No        88      1009
#
#       Temperature  UVIndex  WindSpeed  ACTScore
# 0            23.9        1        6.7        14
# 1            25.0        1        0.8        15
# 2            23.9        0        3.1        15
# 3            22.7        1        1.1        13
# 4            24.9        1        5.1        15
# ...           ...      ...        ...       ...
# 1005         27.0        1        1.3        18
# 1006         25.4        1        1.0        18
# 1007         25.6        1        1.0        19
# 1008         29.7        0        0.9        17
# 1009         25.0        1        2.1        19
#
# [1010 rows x 14 columns]

# %%
# drop unnecessary data

data = Data.drop(['UserNo.', 'UserID'],axis =1)

data
# Out:
#       Location  Age  Gender  OutdoorJob  OutdoorActivities SmokingHabit  \
# 0            4    3       1           1                  0           No
# 1            4    3       1           1                  0           No
# 2            4    3       1           1                  0           No
# 3            4    3       1           1                  0           No
# 4            4    3       1           1                  0           No
# ...        ...  ...     ...         ...                ...          ...
# 1005         3    1       1           2                  2           No
# 1006         3    1       1           2                  2           No
# 1007         3    1       1           2                  2           No
# 1008         3    1       1           2                  2           No
# 1009         3    1       1           2                  2           No
#
#       Humidity  Pressure  Temperature  UVIndex  WindSpeed  ACTScore
# 0          100      1011         23.9        1        6.7        14
# 1           94      1010         25.0        1        0.8        15
# 2           88      1008         23.9        0        3.1        15
# 3           94      1009         22.7        1        1.1        13
# 4           83      1008         24.9        1        5.1        15
# ...        ...       ...          ...      ...        ...       ...
# 1005        94      1010         27.0        1        1.3        18
# 1006        78      1011         25.4        1        1.0        18
# 1007        83      1010         25.6        1        1.0        19
# 1008        89      1008         29.7        0        0.9        17
# 1009        88      1009         25.0        1        2.1        19
#
# [1010 rows x 12 columns]

# %%
# describe output variable

data['ACTScore'].describe()
# Out:
# count    1010.000000
# mean       16.576238
# std         4.666969
# min         8.000000
# 25%        12.250000
# 50%        17.000000
# 75%        21.000000
# max        25.000000
# Name: ACTScore, dtype: float64

# %%
# visualise output variable

fig = plt.figure(figsize=(10,7))
fig.add_subplot(2,1,1)
sns.distplot(data['ACTScore'])
fig.add_subplot(2,1,2)
sns.boxplot(data['ACTScore'])
plt.tight_layout()
# Out:
# /var/folders/78/0k0l12sj7tv881mzy3q878_r0000gn/T/ipykernel_67205/2516627335.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['ACTScore'])

# %%
# visualise Temperature

fig = plt.figure(figsize=(60,15),constrained_layout=False)
fig.add_subplot(2,2,1)
sns.countplot(data['Temperature'])

plt.tight_layout()

# %%
# visualise Humidity, Pressure, WindSpeed, UVIndex

fig = plt.figure(figsize=(30,10),constrained_layout=False)
fig.add_subplot(2,2,1)
sns.countplot(data['Humidity'])
fig.add_subplot(2,2,2)
sns.countplot(data['WindSpeed'])
fig.add_subplot(2,2,3)
sns.countplot(data['Pressure'])
fig.add_subplot(2,2,4)
sns.countplot(data['UVIndex'])

plt.tight_layout()

# %%
# check correlation

# data.corr()['ACTScore'].sort_values(ascending=False)

# %%
# show correlation metrix (heatmap)

# corrmat = data.corr()
# f, ax = plt.subplots(figsize=(12, 9))
# sns.heatmap(corrmat, vmax=.8, square=True);

# %%
# k = 12 # number of variables for the heatmap
# cols = corrmat.nlargest(k, 'ACTScore')['ACTScore'].index
# f, ax = plt.subplots(figsize=(20, 10))
# sns.heatmap(data[cols].corr(), vmax=.8, square=True, annot=True );

# %%
# visualise Temperature, Humidity, Pressure, WindSpeed

cols = ['ACTScore', 'Temperature', 'Humidity', 'Pressure', 'WindSpeed']
sns.pairplot(data[cols], height = 3);

# %%
# visualise UVIndex

fig = plt.figure(figsize=(25,8),constrained_layout=False)
fig.add_subplot(2,2,1)
sns.countplot(x="ACTScore", hue="UVIndex", data=Data)

plt.tight_layout()

# %% [markdown]
# # Splitting the Dataset

# %%
# define X as input features and Y as target variable 
X = data.drop(['Location','SmokingHabit', 'ACTScore'],axis =1).values
Y = data['ACTScore'].values

# %%
# split Train and Test 

from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.30, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

s_scaler = StandardScaler()
X_train = s_scaler.fit_transform(X_train.astype(np.float64))
X_test = s_scaler.transform(X_test.astype(np.float64))

# %% [markdown]
# # Deep Neural Network Regression (DNNR)

# %%
# create a DNNR model

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Dense

# %%
# add layers

model1 = Sequential()

model1.add(Dense(16, input_dim=9, activation='relu'))
model1.add(Dense(16, activation='relu'))
model1.add(Dense(1))

model1.compile(optimizer='adam',loss='mean_squared_error')
# Out:
# 2023-12-22 19:14:46.211878: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Max
# 2023-12-22 19:14:46.211900: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 32.00 GB
# 2023-12-22 19:14:46.211904: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 10.67 GB
# 2023-12-22 19:14:46.211950: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-12-22 19:14:46.212135: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# train the model

model1.fit(x=X_train,y=Y_train,
          validation_data=(X_test,Y_test),
          batch_size=128,epochs=1000)
# Out:
# Epoch 1/1000
# 2023-12-22 19:14:46.542273: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 6/6 [==============================] - 1s 43ms/step - loss: 301.3198 - val_loss: 287.9316
# Epoch 2/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 298.5729 - val_loss: 285.4904
# Epoch 3/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 295.8944 - val_loss: 283.1021
# Epoch 4/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 293.3309 - val_loss: 280.7277
# Epoch 5/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 290.7562 - val_loss: 278.3969
# Epoch 6/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 288.2957 - val_loss: 276.0033
# Epoch 7/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 285.7198 - val_loss: 273.6073
# Epoch 8/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 283.0900 - val_loss: 271.2067
# Epoch 9/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 280.5229 - val_loss: 268.7406
# Epoch 10/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 277.8846 - val_loss: 266.2458
# Epoch 11/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 275.1124 - val_loss: 263.7243
# Epoch 12/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 272.5287 - val_loss: 261.1058
# Epoch 13/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 269.5734 - val_loss: 258.4763
# Epoch 14/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 266.6180 - val_loss: 255.8102
# Epoch 15/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 263.7541 - val_loss: 253.0827
# Epoch 16/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 260.7665 - val_loss: 250.3534
# Epoch 17/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 257.7646 - val_loss: 247.5888
# Epoch 18/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 254.7612 - val_loss: 244.7820
# Epoch 19/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 251.6332 - val_loss: 241.9736
# Epoch 20/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 248.4470 - val_loss: 239.1653
# Epoch 21/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 245.5162 - val_loss: 236.3218
# Epoch 22/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 242.1850 - val_loss: 233.5580
# Epoch 23/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 239.0654 - val_loss: 230.8549
# Epoch 24/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 235.9458 - val_loss: 228.2137
# Epoch 25/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 233.1363 - val_loss: 225.6494
# Epoch 26/1000
# 6/6 [==============================] - 0s 12ms/step - loss:
1000
# 6/6 [==============================] - 0s 10ms/step - loss: 37.2520 - val_loss: 35.2800
# Epoch 133/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 35.9909 - val_loss: 34.4190
# Epoch 134/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 34.8263 - val_loss: 32.9027
# Epoch 135/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 33.2963 - val_loss: 31.5902
# Epoch 136/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 32.1667 - val_loss: 30.5848
# Epoch 137/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 31.0016 - val_loss: 29.5143
# Epoch 138/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 29.9633 - val_loss: 28.4775
# Epoch 139/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 28.9365 - val_loss: 27.5382
# Epoch 140/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 28.0034 - val_loss: 26.4179
# Epoch 141/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 26.7940 - val_loss: 25.7408
# Epoch 142/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 26.0795 - val_loss: 24.6144
# Epoch 143/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 24.9622 - val_loss: 23.7320
# Epoch 144/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 24.1320 - val_loss: 22.9947
# Epoch 145/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 23.2728 - val_loss: 22.1291
# Epoch 146/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 22.4408 - val_loss: 21.5802
# Epoch 147/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 21.7891 - val_loss: 20.6583
# Epoch 148/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 20.9474 - val_loss: 19.9637
# Epoch 149/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 20.1660 - val_loss: 19.1556
# Epoch 150/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 19.4737 - val_loss: 18.5240
# Epoch 151/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 18.6641 - val_loss: 17.7317
# Epoch 152/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 18.0528 - val_loss: 17.0856
# Epoch 153/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 17.3275 - val_loss: 16.6236
# Epoch 154/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 16.6501 - val_loss: 15.9385
# Epoch 155/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 16.2046 - val_loss: 15.4192
# Epoch 156/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 15.5938 - val_loss: 15.1293
# Epoch 157/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 15.1077 - val_loss: 14.4946
# Epoch 158/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 14.8651 - val_loss: 14.0607
# Epoch 159/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 14.3445 - val_loss: 13.6341
# Epoch 160/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 13.8420 - val_loss: 13.2190
# Epoch 161/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 13.3624 - val_loss: 12.9186
# Epoch 162/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 13.0412 - val_loss: 12.5004
# Epoch 163/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 12.6520 - val_loss: 12.1545
# Epoch 164/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 12.3354 - val_loss: 11.8789
# Epoch 165/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 11.9775 - val_loss: 11.5037
# Epoch 166/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 11.6382 - val_loss: 11.2006
# Epoch 167/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 11.3202 - val_loss: 10.9326
# Epoch 168/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 11.0675 - val_loss: 10.6320
# Epoch 169/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 10.7904 - val_loss: 10.3948
# Epoch 170/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 10.5224 - val_loss: 10.1140
# Epoch 171/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 10.2594 - val_loss: 9.9137
# Epoch 172/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 10.0747 - val_loss: 9.6334
# Epoch 173/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 9.7826 - val_loss: 9.5277
# Epoch 174/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 9.7050 - val_loss: 9.2055
# Epoch 175/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 9.4002 - val_loss: 9.0302
# Epoch 176/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 9.1947 - val_loss: 8.8362
# Epoch 177/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 9.0740 - val_loss: 8.7672
# Epoch 178/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 9.0256 - val_loss: 8.5509
# Epoch 179/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 9.0503 - val_loss: 8.3840
# Epoch 180/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 8.6484 - val_loss: 8.1353
# Epoch 181/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 8.4329 - val_loss: 8.0079
# Epoch 182/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 8.3999 - val_loss: 7.8975
# Epoch 183/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 8.1731 - val_loss: 7.8249
# Epoch 184/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 8.1168 - val_loss: 7.7248
# Epoch 185/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 8.0050 - val_loss: 7.6750
# Epoch 186/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 7.9003 - val_loss: 7.4619
# Epoch 187/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 7.7889 - val_loss: 7.4191
# Epoch 188/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 7.8030 - val_loss: 7.4135
# Epoch 189/1000
# 6/6 [==============================] - 0s 11ms/step - loss:
1000
# 6/6 [==============================] - 0s 12ms/step - loss: 6.9719 - val_loss: 6.4059
# Epoch 245/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 6.9829 - val_loss: 6.3999
# Epoch 246/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 6.9736 - val_loss: 6.3925
# Epoch 247/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 6.9738 - val_loss: 6.3913
# Epoch 248/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 6.9985 - val_loss: 6.4293
# Epoch 249/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 7.0282 - val_loss: 6.5252
# Epoch 250/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 7.2217 - val_loss: 6.8786
# Epoch 251/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 7.2249 - val_loss: 6.5535
# Epoch 252/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 7.1653 - val_loss: 6.6367
# Epoch 253/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 7.1920 - val_loss: 6.4469
# Epoch 254/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 7.2002 - val_loss: 6.4548
# Epoch 255/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 7.2191 - val_loss: 6.5991
# Epoch 256/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 7.3147 - val_loss: 6.6061
# Epoch 257/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 7.2286 - val_loss: 6.4761
# Epoch 258/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 7.0843 - val_loss: 6.4955
# Epoch 259/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 7.1100 - val_loss: 6.6256
# Epoch 260/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 7.1429 - val_loss: 6.5027
# Epoch 261/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 7.0935 - val_loss: 6.6075
# Epoch 262/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 7.0979 - val_loss: 6.5044
# Epoch 263/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 7.0880 - val_loss: 6.5126
# Epoch 264/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 7.1652 - val_loss: 6.6991
# Epoch 265/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 7.1537 - val_loss: 6.5246
# Epoch 266/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 7.1346 - val_loss: 6.5235
# Epoch 267/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 7.1318 - val_loss: 6.7330
# Epoch 268/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 7.3292 - val_loss: 6.6445
# Epoch 269/1000
# 1/6 [====>.........................] - ETA: 0s - loss: 7.1455
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 3
#       1 # train the model
# ----> 3 model1.fit(x=X_train,y=Y_train,
#       4           validation_data=(X_test,Y_test),
#       5           batch_size=128,epochs=1000)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/keras/src/engine/training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                160
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 449 (1.75 KB)
# Trainable params: 449 (1.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
loss_df = pd.DataFrame(model1.history.history)
loss_df.plot(figsize=(12,8))
# Out:
# <Axes: >

# %%
# show evaluation metrics
# explained variance score: best possible score is 1 and lower values are worse

from sklearn import metrics

Y_pred1 = model1.predict(X_test)

print('Mean Absolute Error: {:.2f}'.format(metrics.mean_absolute_error(Y_test, Y_pred1)))
print('Mean Squared Error: {:.2f}'.format(metrics.mean_squared_error(Y_test, Y_pred1)))
print('Explained Variance Score: {:.2f}'.format(metrics.explained_variance_score(Y_test, Y_pred1)))
# Out:
# 10/10 [==============================] - 0s 3ms/step
# Mean Absolute Error: 2.00
# Mean Squared Error: 6.62
# Explained Variance Score: 0.70

# %%
# show prediction result
fig = plt.figure(figsize = (10,5))
plt.scatter(Y_test,Y_pred1)
plt.plot(Y_test,Y_test,'r')

# %%
fig2 = plt.figure(figsize=(10,5))
residuals1 = (Y_test- Y_pred1)
sns.distplot(residuals1)
# Out:
# /var/folders/78/0k0l12sj7tv881mzy3q878_r0000gn/T/ipykernel_10391/1870692961.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residuals1)
# <Axes: ylabel='Density'>

# %%
Y_test
# Out:
# array([13, 16, 25, 19, 20, 12, 10, 20, 24, 21, 12, 23, 21, 24, 22, 17, 23,
#        13, 13, 21, 13, 11, 10, 22, 13, 11, 17,  8, 11, 15, 18, 10, 22, 19,
#        17, 21, 14, 18, 15, 19, 15, 12, 20, 24, 10, 10,  8, 10, 19, 20, 20,
#        24, 21, 15, 18, 17, 13, 21, 10, 13, 21,  8, 10, 14, 14, 16, 13, 19,
#        17, 19, 22, 14, 10, 18, 23, 21, 21, 13, 14, 14, 14, 11, 21, 10, 20,
#         9, 12,  8, 11, 15, 19,  9, 14, 13, 12, 13, 16, 21, 20, 21, 12, 18,
#        14, 19, 24, 11,  8, 19, 21, 19, 20,  9, 11, 20, 14, 20, 19, 10, 12,
#        11, 21, 20, 21, 19, 11, 10, 17, 19, 25, 21, 20, 21, 25, 15, 18, 17,
#        21, 21, 25, 14, 22, 21, 21, 12, 21, 15, 19, 19, 11, 17, 20, 16, 13,
#        20, 12, 18, 19, 15,  9, 21, 23, 20, 24, 24, 14, 18, 20,  8, 23, 14,
#        20, 12, 17, 15, 23, 13, 18, 13,  8, 15,  9,  9, 10, 15, 14,  8, 12,
#        20, 16, 12, 20, 14, 20, 14, 19, 14, 18, 11, 18, 17, 15, 23, 14, 10,
#        11, 10, 20, 14, 19, 23, 22, 21, 21, 23, 13, 11, 17, 11, 19, 25, 10,
#        12,  8,  8, 17, 22, 15, 15, 15, 12, 15, 20,  8, 21, 15,  8, 15, 12,
#        23, 13, 18, 24, 13, 18, 13, 11, 21, 23, 25, 20, 20, 14, 21, 14, 15,
#        13, 13,  9,  9, 19, 13, 15, 11, 22, 13, 19, 20, 10, 11, 17, 14, 22,
#        17, 21, 20,  9, 11, 14, 17, 14, 22, 18, 10, 12, 20,  9, 19, 14, 17,
#        17, 23, 23, 19, 22, 25, 21, 18, 12, 23, 19, 14, 19, 12])

# %%
Y_pred1
# Out:
# array([[10.294855 ],
#        [17.546015 ],
#        [20.704615 ],
#        [16.240076 ],
#        [21.90362  ],
#        [15.107286 ],
#        [10.057398 ],
#        [18.076685 ],
#        [20.718561 ],
#        [18.165262 ],
#        [11.721521 ],
#        [19.054193 ],
#        [20.434137 ],
#        [21.795801 ],
#        [20.18194  ],
#        [15.671213 ],
#        [22.089197 ],
#        [15.645823 ],
#        [11.4804325],
#        [21.621729 ],
#        [16.49795  ],
#        [12.233118 ],
#        [11.678522 ],
#        [20.9302   ],
#        [10.436426 ],
#        [11.001062 ],
#        [18.016802 ],
#        [10.59469  ],
#        [14.401453 ],
#        [15.815111 ],
#        [18.120691 ],
#        [ 9.093531 ],
#        [22.72909  ],
#        [17.845835 ],
#        [16.098734 ],
#        [18.379541 ],
#        [13.3849125],
#        [17.719995 ],
#        [18.175997 ],
#        [20.844446 ],
#        [16.072641 ],
#        [13.524256 ],
#        [21.903559 ],
#        [23.830889 ],
#        [10.169458 ],
#        [14.034052 ],
#        [16.182154 ],
#        [13.785059 ],
#        [16.098444 ],
#        [16.9909   ],
#        [19.194223 ],
#        [18.723291 ],
#        [19.569452 ],
#        [14.1488285],
#        [16.441607 ],
#        [16.055994 ],
#        [16.030512 ],
#        [21.34231  ],
#        [13.517435 ],
#        [16.987574 ],
#        [20.192102 ],
#        [14.4994755],
#        [20.930506 ],
#        [17.82046  ],
#        [10.044947 ],
#        [10.705683 ],
#        [ 9.148767 ],
#        [18.541437 ],
#        [13.455805 ],
#        [17.719217 ],
#        [19.71316  ],
#        [22.932093 ],
#        [17.961283 ],
#        [19.98208  ],
#        [17.72117  ],
#        [10.8041935],
#        [13.91366  ],
#        [16.959024 ],
#        [13.546869 ],
#        [15.872263 ],
#        [20.32937  ],
#        [ 9.041101 ],
#        [13.648767 ],
#        [11.461939 ],
#        [16.358957 ],
#        [16.163446 ],
#        [19.25802  ],
#        [12.599634 ],
#        [15.811335 ],
#        [18.034502 ],
#        [10.872797 ],
#        [12.890589 ],
#        [22.430895 ],
#        [14.234049 ],
#        [19.64245  ],
#        [11.195185 ],
#        [10.299189 ],
#        [16.551798 ],
#        [15.089365 ],
#        [24.46432  ],
#        [13.279139 ],
#        [18.650064 ],
#        [22.163568 ],
#        [17.652292 ],
#        [17.279291 ],
#        [13.154673 ],
#        [10.633356 ],
#        [20.590418 ],
#        [24.337427 ],
#        [20.57992  ],
#        [18.154474 ],
#        [17.619623 ],
#        [13.455835 ],
#        [21.344995 ],
#        [13.041773 ],
#        [16.925287 ],
#        [13.296259 ],
#        [13.639154 ],
#        [15.9634495],
#        [13.564081 ],
#        [16.040873 ],
#        [15.515131 ],
#        [11.0185795],
#        [10.859613 ],
#        [21.638758 ],
#        [11.344233 ],
#        [16.737375 ],
#        [19.929926 ],
#        [15.685358 ],
#        [13.861597 ],
#        [16.420603 ],
#        [12.532465 ],
#        [19.555262 ],
#        [17.202204 ],
#        [19.463099 ],
#        [23.862238 ],
#        [15.963358 ],
#        [10.984125 ],
#        [15.003393 ],
#        [17.23472  ],
#        [15.011911 ],
#        [18.538233 ],
#        [19.430994 ],
#        [15.543993 ],
#        [14.965784 ],
#        [22.726038 ],
#        [12.5941105],
#        [17.719217 ],
#        [15.478403 ],
#        [16.562021 ],
#        [16.180628 ],
#        [24.744959 ],
#        [21.947718 ],
#        [16.239862 ],
#        [23.056635 ],
#        [23.441645 ],
#        [23.15066  ],
#        [16.316942 ],
#        [ 9.962305 ],
#        [21.870783 ],
#        [16.657907 ],
#        [14.828581 ],
#        [20.068628 ],
#        [11.138208 ]], dtype=float32)

# %% [markdown]
# # DNNR Model Optimisation

# %% [markdown]
# ### Data scaling

# %%
# apply data standardisation

from sklearn.preprocessing import StandardScaler

TargetVariable =['ACTScore']
Predictors =['Location', 'Age', 'Gender', 'Humidity', 'Pressure', 'Temperature', 'UVIndex', 'WindSpeed', 'OutdoorJob', 'OutdoorActivities']

X = data[Predictors].values
Y = data[TargetVariable].values

PredictorScaler = StandardScaler()
TargetVarScaler = StandardScaler()

# store the fit object for later reference
PredictorScalerFit = PredictorScaler.fit(X)
TargetVarScalerFit = TargetVarScaler.fit(Y)

# generate the standardised values of X and Y
X = PredictorScalerFit.transform(X)
Y = TargetVarScalerFit.transform(Y)

# split Train and Test 
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.30, random_state=42)

# check the shapes of training and testing datasets
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (707, 10)
# (707, 1)
# (303, 10)
# (303, 1)

# %% [markdown]
# ### Optimisation algorithm

# %% [markdown]
# #### Hidden layers and hidden nodes

# %%
from scikeras.wrappers import KerasRegressor
from sklearn.model_selection import GridSearchCV
    
def FindLayerNodes(n_layers, n_layer_nodes):
    layers = []
    nodes = n_layer_nodes
    return layers

def createmodel(n_layers, n_layer_nodes):
    model = Sequential()
    n_nodes = FindLayerNodes(n_layers, n_layer_nodes)
    for i in range(1, n_layers):
        if i==1:
            model.add(Dense(n_layer_nodes, input_dim=10, activation='relu'))
        else:
            model.add(Dense(n_nodes[i], activation='relu'))
            
    model.add(Dense(1,))
    model.compile(optimizer='adam', loss='mean_squared_error')
    
    return model

model =  KerasRegressor(n_layer_nodes=10,n_layers=2,build_fn=createmodel, verbose=0)

# %%
import time

# starting time
start = time.time()

# find the optimum number of hidden layers and hidden nodes
param_grid1 = dict(n_layers=[2, 3, 4], n_layer_nodes = [10, 20, 30, 50])
grid1 = GridSearchCV(estimator = model, param_grid = param_grid1)
grid1.fit(X,Y)

# summarise results
print('Best score: %s' % grid1.best_score_)
print('Best parameters: %s' % grid1.best_params_)

# calculate time
end = time.time()
print(f'Total time taken: {end - start}')
# Out:
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# /Users/nkumar/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:915: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 9
#       7 param_grid1 = dict(n_layers=[2, 3, 4], n_layer_nodes = [10, 20, 30, 50])
#       8 grid1 = GridSearchCV(estimator = model, param_grid = param_grid1)
# ----> 9 grid1.fit(X,Y)
#      11 # summarise results
#      12 print('Best score: %s' % grid1.best_score_)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/sklearn/model_selection/_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1422, in GridSearchCV._run_search(self, evaluate_candidates)
#    1420 def _run_search(self, evaluate_candidates):
#    1421     """Search all candidates in param_grid"""
# -> 1422     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/sklearn/model_selection/_search.py:845, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     837 if self.verbose > 0:
#     838     print(
#     839         "Fitting {0} folds for each of {1} candidates,"
#     840         " totalling {2} fits".format(
#     841             n_splits, n_candidates, n_candidates * n_splits
#     842         )
#     843     )
# --> 845 out = parallel(
#     846     delayed(_fit_and_score)(
#     847         clone(base_estimator),
#     848         X,
#     849         y,
#     850         train=train,
#     851         test=test,
#     852         parameters=parameters,
#     853         split_progress=(split_idx, n_splits),
#     854         candidate_progress=(cand_idx, n_candidates),
#     855         **fit_and_score_kwargs,
#     856     )
#     857     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     858         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     859     )
#     860 )
#     862 if len(out) < 1:
#     863     raise ValueError(
#     864         "No fits were performed. "
#     865         "Was the CV iterator empty? "
#     866         "Were there no candidates?"
#     867     )
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/sklearn/utils/parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/joblib/parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/joblib/parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/sklearn/utils/parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:751, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     748 result["fit_error"] = None
#     750 fit_time = time.time() - start_time
# --> 751 test_scores = _score(estimator, X_test, y_test, scorer, error_score)
#     752 score_time = time.time() - start_time - fit_time
#     753 if return_train_score:
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:810, in _score(estimator, X_test, y_test, scorer, error_score)
#     808         scores = scorer(estimator, X_test)
#     809     else:
# --> 810         scores = scorer(estimator, X_test, y_test)
#     811 except Exception:
#     812     if isinstance(scorer, _MultimetricScorer):
#     813         # If `_MultimetricScorer` raises exception, the `error_score`
#     814         # parameter is equal to "raise".
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/sklearn/metrics/_scorer.py:527, in _PassthroughScorer.__call__(self, estimator, *args, **kwargs)
#     525 def __call__(self, estimator, *args, **kwargs):
#     526     """Method that wraps estimator.score"""
# --> 527     return estimator.score(*args, **kwargs)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:1111, in BaseWrapper.score(self, X, y, sample_weight)
#    1106     X, y, sample_weight = self._validate_sample_weight(
#    1107         X=X, y=y, sample_weight=sample_weight
#    1108     )
#    1110 # compute Keras model score
# -> 1111 y_pred = self.predict(X)
#    1113 # filter kwargs and get attributes for score
#    1114 params = self.get_params()
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:1048, in BaseWrapper.predict(self, X, **kwargs)
#    1024 """Returns predictions for the given test data.
#    1025
#    1026 Parameters
#    (...)
#    1045     Predictions, of shape shape (n_samples,) or (n_samples, n_outputs).
#    1046 """
#    1047 # predict with Keras model
# -> 1048 y_pred = self._predict_raw(X=X, **kwargs)
#    1050 # post process y
#    1051 y_pred = self.target_encoder_.inverse_transform(y_pred)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:1019, in BaseWrapper._predict_raw(self, X, **kwargs)
#    1014             raise ValueError(
#    1015                 "`batch_size=-1` requires that `X` implement `shape`"
#    1016             ) from None
#    1018 # predict with Keras model
# -> 1019 y_pred = self.model_.predict(x=X, **pred_args)
#    1021 return y_pred
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/keras/src/engine/training.py:2655, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2653 for step in data_handler.steps():
#    2654     callbacks.on_predict_batch_begin(step)
# -> 2655     tmp_batch_outputs = self.predict_function(iterator)
#    2656     if data_handler.should_sync:
#    2657         context.async_wait()
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:888, in Function._call(self, *args, **kwds)
#     885 try:
#     886   # This is the first call of __call__, so we have to initialize.
#     887   initializers = []
# --> 888   self._initialize(args, kwds, add_initializers_to=initializers)
#     889 finally:
#     890   # At this point we know that the initialization is complete (or less
#     891   # interestingly an exception was raised) so we no longer need a lock.
#     892   self._lock.release()
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:695, in Function._initialize(self, args, kwds, add_initializers_to)
#     690 self._variable_creation_config = self._generate_scoped_tracing_options(
#     691     variable_capturing_scope,
#     692     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     693 )
#     694 # Force the definition of the function for these arguments
# --> 695 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     696     args, kwds, self._variable_creation_config
#     697 )
#     699 def invalid_creator_scope(*unused_args, **unused_kwds):
#     700   """Disables variable creation."""
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/framework/func_graph.py:1059, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056   return x
#    1058 _, original_func = tf_decorator.unwrap(python_func)
# -> 1059 func_outputs = python_func(*func_args, **func_kwargs)
#    1061 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1062 # TensorArrays and `None`s.
#    1063 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:598, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     594 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     595   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     596   # the function a weak reference to itself to avoid a reference cycle.
#     597   with OptionalXlaContext(compile_with_xla):
# --> 598     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     599   return out
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/autograph_util.py:41, in py_func_from_autograph.<locals>.autograph_handler(*args, **kwargs)
#      39 """Calls a converted version of original_func."""
#      40 try:
# ---> 41   return api.converted_call(
#      42       original_func,
#      43       args,
#      44       kwargs,
#      45       options=converter.ConversionOptions(
#      46           recursive=True,
#      47           optional_features=autograph_options,
#      48           user_requested=True,
#      49       ))
#      50 except Exception as e:  # pylint:disable=broad-except
#      51   if hasattr(e, "ag_error_metadata"):
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File /var/folders/78/0k0l12sj7tv881mzy3q878_r0000gn/T/__autograph_generated_fileo5n5f68_.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__predict_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:460, in _call_unconverted(f, args, kwargs, options, update_cache)
#     458 if kwargs is not None:
#     459   return f(*args, **kwargs)
# --> 460 return f(*args)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/keras/src/engine/training.py:2425, in Model.make_predict_function.<locals>.step_function(model, iterator)
#    2420     run_step = tf.function(
#    2421         run_step, jit_compile=True, reduce_retracing=True
#    2422     )
#    2424 data = next(iterator)
# -> 2425 outputs = model.distribute_strategy.run(run_step, args=(data,))
#    2426 outputs = reduce_per_replica(
#    2427     outputs, self.distribute_strategy, reduction="concat"
#    2428 )
#    2429 return outputs
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/distribute/distribute_lib.py:1681, in StrategyBase.run(***failed resolving arguments***)
#    1676 with self.scope():
#    1677   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1678   # applied when the caller is also in Eager mode.
#    1679   fn = autograph.tf_convert(
#    1680       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1681   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/distribute/distribute_lib.py:3271, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    3269   kwargs = {}
#    3270 with self._container_strategy().scope():
# -> 3271   return self._call_for_each_replica(fn, args, kwargs)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/distribute/distribute_lib.py:4069, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    4067 def _call_for_each_replica(self, fn, args, kwargs):
#    4068   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 4069     return fn(*args, **kwargs)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:690, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     688 try:
#     689   with conversion_ctx:
# --> 690     return converted_call(f, args, kwargs, options=options)
#     691 except Exception as e:  # pylint:disable=broad-except
#     692   if hasattr(e, 'ag_error_metadata'):
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/keras/src/engine/training.py:2413, in Model.make_predict_function.<locals>.step_function.<locals>.run_step(data)
#    2412 def run_step(data):
# -> 2413     outputs = model.predict_step(data)
#    2414     # Ensure counter is updated only if `test_step` succeeds.
#    2415     with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/keras/src/engine/training.py:2381, in Model.predict_step(self, data)
#    2361 """The logic for one inference step.
#    2362
#    2363 This method can be overridden to support custom inference logic.
#    (...)
#    2378   `Model` on data.
#    2379 """
#    2380 x, _, _ = data_adapter.unpack_x_y_sample_weight(data)
# -> 2381 return self(x, training=False)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/keras/src/engine/training.py:590, in Model.__call__(self, *args, **kwargs)
#     586         super().__call__(inputs, *copied_args, **copied_kwargs)
#     588     layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 590 return super().__call__(*args, **kwargs)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/keras/src/engine/base_layer.py:1149, in Layer.__call__(self, *args, **kwargs)
#    1144     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1146 with autocast_variable.enable_auto_cast_variables(
#    1147     self._compute_dtype_object
#    1148 ):
# -> 1149     outputs = call_fn(inputs, *args, **kwargs)
#    1151 if self._activity_regularizer:
#    1152     self._handle_activity_regularization(inputs, outputs)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:690, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     688 try:
#     689   with conversion_ctx:
# --> 690     return converted_call(f, args, kwargs, options=options)
#     691 except Exception as e:  # pylint:disable=broad-except
#     692   if hasattr(e, 'ag_error_metadata'):
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/keras/src/engine/sequential.py:398, in Sequential.call(self, inputs, training, mask)
#     396     if not self.built:
#     397         self._init_graph_network(self.inputs, self.outputs)
# --> 398     return super().call(inputs, training=training, mask=mask)
#     400 outputs = inputs  # handle the corner case where self.layers is empty
#     401 for layer in self.layers:
#     402     # During each iteration, `inputs` are the inputs to `layer`, and
#     403     # `outputs` are the outputs of `layer` applied to `inputs`. At the
#     404     # end of each iteration `inputs` is set to `outputs` to prepare for
#     405     # the next layer.
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/keras/src/engine/functional.py:515, in Functional.call(self, inputs, training, mask)
#     496 @doc_controls.do_not_doc_inheritable
#     497 def call(self, inputs, training=None, mask=None):
#     498     """Calls the model on new inputs.
#     499
#     500     In this case `call` just reapplies
#    (...)
#     513         a list of tensors if there are more than one outputs.
#     514     """
# --> 515     return self._run_internal_graph(inputs, training=training, mask=mask)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/keras/src/engine/functional.py:672, in Functional._run_internal_graph(self, inputs, training, mask)
#     669     continue  # Node is not computable, try skipping.
#     671 args, kwargs = node.map_arguments(tensor_dict)
# --> 672 outputs = node.layer(*args, **kwargs)
#     674 # Update tensor_dict.
#     675 for x_id, y in zip(
#     676     node.flat_output_ids, tf.nest.flatten(outputs)
#     677 ):
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/keras/src/engine/base_layer.py:1149, in Layer.__call__(self, *args, **kwargs)
#    1144     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1146 with autocast_variable.enable_auto_cast_variables(
#    1147     self._compute_dtype_object
#    1148 ):
# -> 1149     outputs = call_fn(inputs, *args, **kwargs)
#    1151 if self._activity_regularizer:
#    1152     self._handle_activity_regularization(inputs, outputs)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:690, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     688 try:
#     689   with conversion_ctx:
# --> 690     return converted_call(f, args, kwargs, options=options)
#     691 except Exception as e:  # pylint:disable=broad-except
#     692   if hasattr(e, 'ag_error_metadata'):
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/keras/src/layers/core/dense.py:241, in Dense.call(self, inputs)
#     237         outputs = tf.nn.embedding_lookup_sparse(
#     238             self.kernel, ids, weights, combiner="sum"
#     239         )
#     240     else:
# --> 241         outputs = tf.matmul(a=inputs, b=self.kernel)
#     242 # Broadcast kernel to inputs.
#     243 else:
#     244     outputs = tf.tensordot(inputs, self.kernel, [[rank - 1], [0]])
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/ops/weak_tensor_ops.py:142, in weak_tensor_binary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#     140 def wrapper(*args, **kwargs):
#     141   if not ops.is_auto_dtype_conversion_enabled():
# --> 142     return op(*args, **kwargs)
#     143   bound_arguments = signature.bind(*args, **kwargs)
#     144   bound_arguments.apply_defaults()
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:140, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     138 def error_handler(*args, **kwargs):
#     139   try:
# --> 140     if not is_traceback_filtering_enabled():
#     141       return fn(*args, **kwargs)
#     142   except NameError:
#     143     # In some very rare cases,
#     144     # `is_traceback_filtering_enabled` (from the outer scope) may not be
#     145     # accessible from inside this function
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:47, in is_traceback_filtering_enabled()
#      32 @tf_export('debugging.is_traceback_filtering_enabled')
#      33 def is_traceback_filtering_enabled():
#      34   """Check whether traceback filtering is currently enabled.
#      35
#      36   See also `tf.debugging.enable_traceback_filtering()` and
#    (...)
#      45     was called).
#      46   """
# ---> 47   value = getattr(_ENABLE_TRACEBACK_FILTERING, 'value', True)
#      48   return value
#
# KeyboardInterrupt:

# %% [markdown]
# #### Bach size and epochs

# %%
# starting time
start = time.time()

# find the optimum bacth size
param_grid2 = dict(n_layers=[2], n_layer_nodes = [50], batch_size = [10,20])
grid2 = GridSearchCV(estimator = model, param_grid = param_grid2)
grid2.fit(X,Y)

# summarise results
print('Best score: %s' % grid2.best_score_)
print('Best parameters: %s' % grid2.best_params_)

# calculate time
end = time.time()
print(f'Total time taken: {end - start}')
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# starting time
start = time.time()

# find the optimum number of epochs
param_grid2 = dict(n_layers=[2], n_layer_nodes = [50], batch_size = [10], epochs = [100,200])
grid2 = GridSearchCV(estimator = model, param_grid = param_grid2)
grid2.fit(X,Y)

# summarise results
print('Best score: %s' % grid2.best_score_)
print('Best parameters: %s' % grid2.best_params_)

# calculate time
end = time.time()
print(f'Total time taken: {end - start}')
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# #### Optimiser

# %%
# starting time
start = time.time()

# find the optimiser
from sklearn.metrics import make_scorer

def make_regression_dnnr(Optimizer_trial):
        
    model = Sequential()
    model.add(Dense(units=50, input_dim=10, activation='relu'))
    model.add(Dense(units=50, activation='relu'))
    model.add(Dense(1,))
    model.compile(loss='mean_squared_error', optimizer=Optimizer_trial)
    return model

param_grid3 = {'Optimizer_trial':['sgd', 'adam', 'rmsprop']}

model = KerasRegressor(make_regression_dnnr, verbose=False,Optimizer_trial='sgd')

# create the GridSearchCV
grid3 = GridSearchCV(estimator=model, param_grid = param_grid3)

# apply GridSearchCV for paramenters
grid3.fit(X,Y, verbose=0)

# summarise results
print('Best score: %s' % grid3.best_score_)
print('Best optimiser: %s' % grid3.best_params_)

# calculate time
end = time.time()
print(f'Total time taken: {end - start}')
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# #### Loss function

# %%
# starting time
start = time.time()

# find the loss function 
from sklearn.metrics import make_scorer

def make_regression_dnnr(Loss_function):
        
    model = Sequential()
    model.add(Dense(units=50, input_dim=10, activation='relu'))
    model.add(Dense(units=50, activation='relu'))
    model.add(Dense(1,))
    model.compile(loss=Loss_function, optimizer='adam')
    return model

param_grid4 = {'Loss_function':['mae', 'mse', 'mape']}

model = KerasRegressor(make_regression_dnnr, verbose=False,Loss_function='mae')

# create the GridSearchCV
grid4 = GridSearchCV(estimator=model, param_grid = param_grid4)

# apply GridSearchCV for paramenters
grid4.fit(X,Y, verbose=0)

# summarise results
print('Best score: %s' % grid4.best_score_)
print('Best loss function: %s' % grid4.best_params_)

# calculate time
end = time.time()
print(f'Total time taken: {end - start}')
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# #### Weight initialiser

# %%
# starting time
start = time.time()

# find the optimum weight initialiser
def create_model(init_mode):
    # create model
    model = Sequential()
    model.add(Dense(50, input_dim=10, kernel_initializer=init_mode, activation='relu'))
    model.add(Dense(50, kernel_initializer=init_mode, activation='relu'))
    model.add(Dense(1, kernel_initializer=init_mode))
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# create model
model = KerasRegressor(build_fn=create_model, epochs=100, batch_size=10, verbose=0,init_mode='uniform')

# define the grid search parameters
init_mode = ['uniform', 'normal']
param_grid5 = dict(init_mode=init_mode)
grid5 = GridSearchCV(estimator=model, param_grid =param_grid5)
grid5.fit(X, Y)

# summarise results
print('Best score: %s' % grid5.best_score_)
print('Best initialiser: %s' % grid5.best_params_)

# calculate time
end = time.time()
print(f'Total time taken: {end - start}')
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# # Optimised DNNR

# %%
# define the optimised model

model2 = Sequential()

model2.add(Dense(units=50, input_dim=10, kernel_initializer='normal', activation='relu'))
model2.add(Dense(units=50, kernel_initializer='normal', activation='relu'))

model2.add(Dense(1, kernel_initializer='normal'))
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# apply optimiser

model2.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# starting time
import time
start = time.time()

model2.fit(x=X_train,y=Y_train,
          validation_data=(X_test,Y_test),
          batch_size=10,epochs=100)

# calculate time
end = time.time()
print(f'Total time taken: {end - start}')
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
model2.summary()
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
loss_df = pd.DataFrame(model2.history.history)
loss_df.plot(figsize=(12,8))
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
Y_pred2 = model2.predict(X_test)
X_test
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# evaluation metrics
# explained variance score: best possible score is 1 and lower values are worse
from sklearn import metrics

print('Mean Absolute Error: {:.2f}'.format(metrics.mean_absolute_error(Y_test, Y_pred2)))
print('Mean Squared Error: {:.2f}'.format(metrics.mean_squared_error(Y_test, Y_pred2)))
print('Explained Variance Score: {:.2f}'.format(metrics.explained_variance_score(Y_test,Y_pred2)))
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# show prediction result
fig3 = plt.figure(figsize = (10,5))
plt.scatter(Y_test,Y_pred2)
plt.plot(Y_test,Y_test,'r')
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# show residuals
fig4 = plt.figure(figsize = (10,5))
residuals2 = (Y_test - Y_pred2)
sns.distplot(residuals2)
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# generate predictions on testing set
Predictions = model2.predict(X_test)
 
# scale the predicted ACTScore back to original ACTScore scale
Predictions = TargetVarScalerFit.inverse_transform(Predictions)
 
# scale the Y_test ACTScore data back to original ACTScore scale
Y_test_orig = TargetVarScalerFit.inverse_transform(Y_test)
 
# scale the test data back to original scale
Test_Data = PredictorScalerFit.inverse_transform(X_test)
 
TestingData = pd.DataFrame(data = Test_Data, columns = Predictors)
TestingData['ACTScore'] = Y_test_orig
TestingData['PredictedACTScore'] = Predictions
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# compute the total accuracy from absolute error
Absolute_Error = 100 * (abs(TestingData['ACTScore'] - TestingData['PredictedACTScore']) / TestingData['ACTScore'])
TestingData['APE'] = Absolute_Error

print('The Accuracy of the optimised DNNR model is:', 100-np.mean(Absolute_Error))
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# compare the prediction with real ACTScore for the first column
ACT_prediction = data['ACTScore'][0]

print ("Original ACT Score = 14")
print ("Predicted ACT Score =", ACT_prediction)
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
