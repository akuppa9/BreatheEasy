# %% [markdown]
# # Optimised Deep Neural Network model to Predict Asthma Exacerbation based on Personalised Weather Triggers

# %%
# import required libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=DeprecationWarning)

# %%
# read the csv file 

Data = pd.read_csv('AsthmaFiles/210526WeAdatasetRegression.csv')

# %% [markdown]
# # Exploratory Data Analysis

# %%
# show the dataset

Data
# Out:
#       UserNo.                        UserID      Location       Age Gender  \
# 0           1  5QBEe959GPOxv3rDNYXZXCEBOfB2      Petaling  Above 50   Male
# 1           1  5QBEe959GPOxv3rDNYXZXCEBOfB2      Petaling  Above 50   Male
# 2           1  5QBEe959GPOxv3rDNYXZXCEBOfB2      Petaling  Above 50   Male
# 3           1  5QBEe959GPOxv3rDNYXZXCEBOfB2      Petaling  Above 50   Male
# 4           1  5QBEe959GPOxv3rDNYXZXCEBOfB2      Petaling  Above 50   Male
# ...       ...                           ...           ...       ...    ...
# 1005       10  b53sAlbpdKesHxsTCiTRPL9SmGx2  Kuala Lampur     31-40   Male
# 1006       10  b53sAlbpdKesHxsTCiTRPL9SmGx2  Kuala Lampur     31-40   Male
# 1007       10  b53sAlbpdKesHxsTCiTRPL9SmGx2  Kuala Lampur     31-40   Male
# 1008       10  b53sAlbpdKesHxsTCiTRPL9SmGx2  Kuala Lampur     31-40   Male
# 1009       10  b53sAlbpdKesHxsTCiTRPL9SmGx2  Kuala Lampur     31-40   Male
#
#         OutdoorJob  OutdoorActivities SmokingHabit  Humidity  Pressure  \
# 0     Occasionally   Extremely likely           No       100      1011
# 1     Occasionally   Extremely likely           No        94      1010
# 2     Occasionally   Extremely likely           No        88      1008
# 3     Occasionally   Extremely likely           No        94      1009
# 4     Occasionally   Extremely likely           No        83      1008
# ...            ...                ...          ...       ...       ...
# 1005        Rarely  Not at all likely           No        94      1010
# 1006        Rarely  Not at all likely           No        78      1011
# 1007        Rarely  Not at all likely           No        83      1010
# 1008        Rarely  Not at all likely           No        89      1008
# 1009        Rarely  Not at all likely           No        88      1009
#
#       Temperature  UVIndex  WindSpeed  ACTScore
# 0            23.9      Low        6.7        14
# 1            25.0      Low        0.8        15
# 2            23.9  Extreme        3.1        15
# 3            22.7      Low        1.1        13
# 4            24.9      Low        5.1        15
# ...           ...      ...        ...       ...
# 1005         27.0      Low        1.3        18
# 1006         25.4      Low        1.0        18
# 1007         25.6      Low        1.0        19
# 1008         29.7  Extreme        0.9        17
# 1009         25.0      Low        2.1        19
#
# [1010 rows x 14 columns]

# %%
# get some information about the dataset

Data.info()
Data.describe().transpose()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1010 entries, 0 to 1009
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   UserNo.            1010 non-null   int64
#  1   UserID             1010 non-null   object
#  2   Location           1010 non-null   object
#  3   Age                1010 non-null   object
#  4   Gender             1010 non-null   object
#  5   OutdoorJob         1010 non-null   object
#  6   OutdoorActivities  1010 non-null   object
#  7   SmokingHabit       1010 non-null   object
#  8   Humidity           1010 non-null   int64
#  9   Pressure           1010 non-null   int64
#  10  Temperature        1010 non-null   float64
#  11  UVIndex            1010 non-null   object
#  12  WindSpeed          1010 non-null   float64
#  13  ACTScore           1010 non-null   int64
# dtypes: float64(2), int64(4), object(8)
# memory usage: 110.6+ KB
#               count         mean        std     min      25%     50%     75%  \
# UserNo.      1010.0     3.932673   2.542293     1.0     3.00     3.0     6.0
# Humidity     1010.0    81.748515  13.542801    40.0    70.00    87.0    93.0
# Pressure     1010.0  1009.264356   2.114750  1003.0  1008.00  1009.0  1011.0
# Temperature  1010.0    27.610990   2.915736    21.1    25.20    27.5    30.1
# WindSpeed    1010.0     2.373069   1.569837     0.0     1.00     2.1     3.3
# ACTScore     1010.0    16.576238   4.666969     8.0    12.25    17.0    21.0
#
#                 max
# UserNo.        10.0
# Humidity      100.0
# Pressure     1014.0
# Temperature    34.5
# WindSpeed       6.7
# ACTScore       25.0

# %%
# check if there are any Null values

Data.isnull().sum()
# Out:
# UserNo.              0
# UserID               0
# Location             0
# Age                  0
# Gender               0
# OutdoorJob           0
# OutdoorActivities    0
# SmokingHabit         0
# Humidity             0
# Pressure             0
# Temperature          0
# UVIndex              0
# WindSpeed            0
# ACTScore             0
# dtype: int64

# %%
# convert categorical data

from sklearn.preprocessing import LabelEncoder

Data['Location'] = LabelEncoder().fit_transform(Data.Location)
Data['Age'] = LabelEncoder().fit_transform(Data.Age)
Data['Gender'] = LabelEncoder().fit_transform(Data.Gender)
Data['OutdoorJob'] = LabelEncoder().fit_transform(Data.OutdoorJob)
Data['OutdoorActivities'] = LabelEncoder().fit_transform(Data.OutdoorActivities)
Data['UVIndex'] = LabelEncoder().fit_transform(Data.UVIndex)

Data
# Out:
#       UserNo.                        UserID  Location  Age  Gender  \
# 0           1  5QBEe959GPOxv3rDNYXZXCEBOfB2         4    3       1
# 1           1  5QBEe959GPOxv3rDNYXZXCEBOfB2         4    3       1
# 2           1  5QBEe959GPOxv3rDNYXZXCEBOfB2         4    3       1
# 3           1  5QBEe959GPOxv3rDNYXZXCEBOfB2         4    3       1
# 4           1  5QBEe959GPOxv3rDNYXZXCEBOfB2         4    3       1
# ...       ...                           ...       ...  ...     ...
# 1005       10  b53sAlbpdKesHxsTCiTRPL9SmGx2         3    1       1
# 1006       10  b53sAlbpdKesHxsTCiTRPL9SmGx2         3    1       1
# 1007       10  b53sAlbpdKesHxsTCiTRPL9SmGx2         3    1       1
# 1008       10  b53sAlbpdKesHxsTCiTRPL9SmGx2         3    1       1
# 1009       10  b53sAlbpdKesHxsTCiTRPL9SmGx2         3    1       1
#
#       OutdoorJob  OutdoorActivities SmokingHabit  Humidity  Pressure  \
# 0              1                  0           No       100      1011
# 1              1                  0           No        94      1010
# 2              1                  0           No        88      1008
# 3              1                  0           No        94      1009
# 4              1                  0           No        83      1008
# ...          ...                ...          ...       ...       ...
# 1005           2                  2           No        94      1010
# 1006           2                  2           No        78      1011
# 1007           2                  2           No        83      1010
# 1008           2                  2           No        89      1008
# 1009           2                  2           No        88      1009
#
#       Temperature  UVIndex  WindSpeed  ACTScore
# 0            23.9        1        6.7        14
# 1            25.0        1        0.8        15
# 2            23.9        0        3.1        15
# 3            22.7        1        1.1        13
# 4            24.9        1        5.1        15
# ...           ...      ...        ...       ...
# 1005         27.0        1        1.3        18
# 1006         25.4        1        1.0        18
# 1007         25.6        1        1.0        19
# 1008         29.7        0        0.9        17
# 1009         25.0        1        2.1        19
#
# [1010 rows x 14 columns]

# %%
# drop unnecessary data

data = Data.drop(['UserNo.', 'UserID'],axis =1)

data
# Out:
#       Location  Age  Gender  OutdoorJob  OutdoorActivities SmokingHabit  \
# 0            4    3       1           1                  0           No
# 1            4    3       1           1                  0           No
# 2            4    3       1           1                  0           No
# 3            4    3       1           1                  0           No
# 4            4    3       1           1                  0           No
# ...        ...  ...     ...         ...                ...          ...
# 1005         3    1       1           2                  2           No
# 1006         3    1       1           2                  2           No
# 1007         3    1       1           2                  2           No
# 1008         3    1       1           2                  2           No
# 1009         3    1       1           2                  2           No
#
#       Humidity  Pressure  Temperature  UVIndex  WindSpeed  ACTScore
# 0          100      1011         23.9        1        6.7        14
# 1           94      1010         25.0        1        0.8        15
# 2           88      1008         23.9        0        3.1        15
# 3           94      1009         22.7        1        1.1        13
# 4           83      1008         24.9        1        5.1        15
# ...        ...       ...          ...      ...        ...       ...
# 1005        94      1010         27.0        1        1.3        18
# 1006        78      1011         25.4        1        1.0        18
# 1007        83      1010         25.6        1        1.0        19
# 1008        89      1008         29.7        0        0.9        17
# 1009        88      1009         25.0        1        2.1        19
#
# [1010 rows x 12 columns]

# %%
# describe output variable

data['ACTScore'].describe()
# Out:
# count    1010.000000
# mean       16.576238
# std         4.666969
# min         8.000000
# 25%        12.250000
# 50%        17.000000
# 75%        21.000000
# max        25.000000
# Name: ACTScore, dtype: float64

# %%
# visualise output variable

fig = plt.figure(figsize=(10,7))
fig.add_subplot(2,1,1)
sns.distplot(data['ACTScore'])
fig.add_subplot(2,1,2)
sns.boxplot(data['ACTScore'])
plt.tight_layout()
# Out:
# /var/folders/78/0k0l12sj7tv881mzy3q878_r0000gn/T/ipykernel_83373/2516627335.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['ACTScore'])

# %%
# visualise Temperature

fig = plt.figure(figsize=(60,15),constrained_layout=False)
fig.add_subplot(2,2,1)
sns.countplot(data['Temperature'])

plt.tight_layout()

# %%
# visualise Humidity, Pressure, WindSpeed, UVIndex

fig = plt.figure(figsize=(30,10),constrained_layout=False)
fig.add_subplot(2,2,1)
sns.countplot(data['Humidity'])
fig.add_subplot(2,2,2)
sns.countplot(data['WindSpeed'])
fig.add_subplot(2,2,3)
sns.countplot(data['Pressure'])
fig.add_subplot(2,2,4)
sns.countplot(data['UVIndex'])

plt.tight_layout()

# %%
# check correlation

# data.corr()['ACTScore'].sort_values(ascending=False)

# %%
# show correlation metrix (heatmap)

# corrmat = data.corr()
# f, ax = plt.subplots(figsize=(12, 9))
# sns.heatmap(corrmat, vmax=.8, square=True);

# %%
# k = 12 # number of variables for the heatmap
# cols = corrmat.nlargest(k, 'ACTScore')['ACTScore'].index
# f, ax = plt.subplots(figsize=(20, 10))
# sns.heatmap(data[cols].corr(), vmax=.8, square=True, annot=True );

# %%
# visualise Temperature, Humidity, Pressure, WindSpeed

cols = ['ACTScore', 'Temperature', 'Humidity', 'Pressure', 'WindSpeed']
sns.pairplot(data[cols], height = 3);

# %%
# visualise UVIndex

fig = plt.figure(figsize=(25,8),constrained_layout=False)
fig.add_subplot(2,2,1)
sns.countplot(x="ACTScore", hue="UVIndex", data=Data)

plt.tight_layout()

# %% [markdown]
# # Splitting the Dataset

# %%
# define X as input features and Y as target variable 
X = data.drop(['SmokingHabit', 'ACTScore'],axis =1).values
Y = data['ACTScore'].values

# %%
# split Train and Test 

from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.30, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

s_scaler = StandardScaler()
X_train = s_scaler.fit_transform(X_train.astype(float))
X_test = s_scaler.transform(X_test.astype(float))

# %% [markdown]
# # Deep Neural Network Regression (DNNR)

# %%
# create a DNNR model

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Dense

# %%
# add layers

model1 = Sequential()

model1.add(Dense(16, input_dim=10, activation='relu'))
model1.add(Dense(16, activation='relu'))
model1.add(Dense(1))

model1.compile(optimizer='adam',loss='mean_squared_error')

# %%
# train the model

model1.fit(x=X_train,y=Y_train,
          validation_data=(X_test,Y_test),
          batch_size=128,epochs=1000)
# Out:
# Epoch 1/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 318.6513 - val_loss: 303.5661
# Epoch 2/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 313.7849 - val_loss: 299.0898
# Epoch 3/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 309.2873 - val_loss: 294.8980
# Epoch 4/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 305.0028 - val_loss: 290.8939
# Epoch 5/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 300.9462 - val_loss: 286.9531
# Epoch 6/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 296.9081 - val_loss: 283.0760
# Epoch 7/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 292.9350 - val_loss: 279.1776
# Epoch 8/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 288.8914 - val_loss: 275.2361
# Epoch 9/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 284.7587 - val_loss: 271.2228
# Epoch 10/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 280.5429 - val_loss: 267.0575
# Epoch 11/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 276.0837 - val_loss: 262.7357
# Epoch 12/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 271.4260 - val_loss: 258.2332
# Epoch 13/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 266.5610 - val_loss: 253.4909
# Epoch 14/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 261.4439 - val_loss: 248.4597
# Epoch 15/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 255.9999 - val_loss: 243.1025
# Epoch 16/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 250.2825 - val_loss: 237.3203
# Epoch 17/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 243.9966 - val_loss: 231.1629
# Epoch 18/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 237.2644 - val_loss: 224.6089
# Epoch 19/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 230.1212 - val_loss: 217.5470
# Epoch 20/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 222.3815 - val_loss: 210.0038
# Epoch 21/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 214.2115 - val_loss: 201.9636
# Epoch 22/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 205.5427 - val_loss: 193.5374
# Epoch 23/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 196.6142 - val_loss: 184.6641
# Epoch 24/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 187.0950 - val_loss: 175.5254
# Epoch 25/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 177.4730 - val_loss: 166.0600
# Epoch 26/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 167.3407 - val_loss: 156.3875
# Epoch 27/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 157.1897 - val_loss: 146.4749
# Epoch 28/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 146.7562 - val_loss: 136.4754
# Epoch 29/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 136.2873 - val_loss: 126.4035
# Epoch 30/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 125.8527 - val_loss: 116.3244
# Epoch 31/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 115.3339 - val_loss: 106.4590
# Epoch 32/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 105.1687 - val_loss: 96.8045
# Epoch 33/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 95.3797 - val_loss: 87.5044
# Epoch 34/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 86.0102 - val_loss: 78.6840
# Epoch 35/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 77.0780 - val_loss: 70.4737
# Epoch 36/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 68.8838 - val_loss: 62.8332
# Epoch 37/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 61.3082 - val_loss: 55.8146
# Epoch 38/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 54.3711 - val_loss: 49.4342
# Epoch 39/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 48.1466 - val_loss: 43.6805
# Epoch 40/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 42.5554 - val_loss: 38.5876
# Epoch 41/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 37.6948 - val_loss: 34.1284
# Epoch 42/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 33.2998 - val_loss: 30.3366
# Epoch 43/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 29.6836 - val_loss: 27.0682
# Epoch 44/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 26.5538 - val_loss: 24.2842
# Epoch 45/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 23.9001 - val_loss: 21.9187
# Epoch 46/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 21.6010 - val_loss: 19.9531
# Epoch 47/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 19.6816 - val_loss: 18.3211
# Epoch 48/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 18.1233 - val_loss: 16.9607
# Epoch 49/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 16.7934 - val_loss: 15.8660
# Epoch 50/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 15.7221 - val_loss: 14.9796
# Epoch 51/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 14.8042 - val_loss: 14.2705
# Epoch 52/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 14.0821 - val_loss: 13.6825
# Epoch 53/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 13.4924 - val_loss: 13.1881
# Epoch 54/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 12.9584 - val_loss: 12.7880
# Epoch 55/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 12.5334 - val_loss: 12.4442
# Epoch 56/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 12.1622 - val_loss: 12.1462
# Epoch 57/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 11.8208 - val_loss: 11.8951
# Epoch 58/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 11.5452 - val_loss: 11.6692
# Epoch 59/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 11.2855 - val_loss: 11.4754
# Epoch 60/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 11.0596 - val_loss: 11.3017
# Epoch 61/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 10.8721 - val_loss: 11.1395
# Epoch 62/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 10.6792 - val_loss: 11.0028
# Epoch 63/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 10.5179 - val_loss: 10.8707
# Epoch 64/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 10.3671 - val_loss: 10.7528
# Epoch 65/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 10.2261 - val_loss: 10.6354
# Epoch 66/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 10.0986 - val_loss: 10.5215
# Epoch 67/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 9.9770 - val_loss: 10.4127
# Epoch 68/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 9.8638 - val_loss: 10.3117
# Epoch 69/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 9.7574 - val_loss: 10.2212
# Epoch 70/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 9.6611 - val_loss: 10.1351
# Epoch 71/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 9.5690 - val_loss: 10.0569
# Epoch 72/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 9.4826 - val_loss: 9.9798
# Epoch 73/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 9.3981 - val_loss: 9.8970
# Epoch 74/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 9.3237 - val_loss: 9.8155
# Epoch 75/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 9.2498 - val_loss: 9.7415
# Epoch 76/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 9.1769 - val_loss: 9.6699
# Epoch 77/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 9.1113 - val_loss: 9.5970
# Epoch 78/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 9.0476 - val_loss: 9.5333
# Epoch 79/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 8.9856 - val_loss: 9.4611
# Epoch 80/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 8.9285 - val_loss: 9.3983
# Epoch 81/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 8.8686 - val_loss: 9.3417
# Epoch 82/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 8.8098 - val_loss: 9.2814
# Epoch 83/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 8.7602 - val_loss: 9.2247
# Epoch 84/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 8.7118 - val_loss: 9.1770
# Epoch 85/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 8.6582 - val_loss: 9.1247
# Epoch 86/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 8.6119 - val_loss: 9.0768
# Epoch 87/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 8.5677 - val_loss: 9.0297
# Epoch 88/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 8.5221 - val_loss: 8.9830
# Epoch 89/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 8.4782 - val_loss: 8.9350
# Epoch 90/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 8.4342 - val_loss: 8.8841
# Epoch 91/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 8.3935 - val_loss: 8.8398
# Epoch 92/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 8.3485 - val_loss: 8.7904
# Epoch 93/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 8.3090 - val_loss: 8.7394
# Epoch 94/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 8.2721 - val_loss: 8.6988
# Epoch 95/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 8.2297 - val_loss: 8.6585
# Epoch 96/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 8.1935 - val_loss: 8.6202
# Epoch 97/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 8.1561 - val_loss: 8.5771
# Epoch 98/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 8.1182 - val_loss: 8.5365
# Epoch 99/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 8.0836 - val_loss: 8.5057
# Epoch 100/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 8
1000
# 6/6 [==============================] - 0s 4ms/step - loss: 2.8407 - val_loss: 3.8264
# Epoch 972/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.8429 - val_loss: 3.7820
# Epoch 973/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 2.8330 - val_loss: 3.7964
# Epoch 974/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 2.8284 - val_loss: 3.7880
# Epoch 975/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 2.8286 - val_loss: 3.8077
# Epoch 976/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 2.8293 - val_loss: 3.7920
# Epoch 977/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.8192 - val_loss: 3.7911
# Epoch 978/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 2.8254 - val_loss: 3.8010
# Epoch 979/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 2.8181 - val_loss: 3.7989
# Epoch 980/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.8177 - val_loss: 3.7914
# Epoch 981/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.8142 - val_loss: 3.7805
# Epoch 982/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 2.8134 - val_loss: 3.8023
# Epoch 983/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 2.8074 - val_loss: 3.7972
# Epoch 984/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 2.8041 - val_loss: 3.7939
# Epoch 985/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 2.8069 - val_loss: 3.7839
# Epoch 986/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 2.8010 - val_loss: 3.7897
# Epoch 987/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 2.8005 - val_loss: 3.7872
# Epoch 988/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7987 - val_loss: 3.7898
# Epoch 989/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 2.7959 - val_loss: 3.7735
# Epoch 990/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7930 - val_loss: 3.7923
# Epoch 991/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7901 - val_loss: 3.7825
# Epoch 992/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 2.7970 - val_loss: 3.7799
# Epoch 993/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 2.7886 - val_loss: 3.7830
# Epoch 994/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7888 - val_loss: 3.7589
# Epoch 995/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 2.7874 - val_loss: 3.7869
# Epoch 996/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 2.7812 - val_loss: 3.7998
# Epoch 997/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.7841 - val_loss: 3.7982
# Epoch 998/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 2.7747 - val_loss: 3.7873
# Epoch 999/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 2.7799 - val_loss: 3.7913
# Epoch 1000/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 2.7749 - val_loss: 3.8014

# %%
model1.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 16)                176
#
#  dense_7 (Dense)             (None, 16)                272
#
#  dense_8 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 465 (1.82 KB)
# Trainable params: 465 (1.82 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
loss_df = pd.DataFrame(model1.history.history)
loss_df.plot(figsize=(12,8))
# Out:
# <Axes: >

# %%
# show evaluation metrics
# explained variance score: best possible score is 1 and lower values are worse

from sklearn import metrics

Y_pred1 = model1.predict(X_test)

print('Mean Absolute Error: {:.2f}'.format(metrics.mean_absolute_error(Y_test, Y_pred1)))
print('Mean Squared Error: {:.2f}'.format(metrics.mean_squared_error(Y_test, Y_pred1)))
print('Explained Variance Score: {:.2f}'.format(metrics.explained_variance_score(Y_test, Y_pred1)))
# Out:
# 10/10 [==============================] - 0s 565us/step
# Mean Absolute Error: 1.46
# Mean Squared Error: 3.80
# Explained Variance Score: 0.83

# %%
# show prediction result
fig = plt.figure(figsize = (10,5))
plt.scatter(Y_test,Y_pred1)
plt.plot(Y_test,Y_test,'r')

# %%
fig2 = plt.figure(figsize=(10,5))
residuals1 = (Y_test- Y_pred1)
sns.distplot(residuals1)
# Out:
# /var/folders/78/0k0l12sj7tv881mzy3q878_r0000gn/T/ipykernel_83373/1870692961.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(residuals1)
# <Axes: ylabel='Density'>

# %%
Y_test
# Out:
# array([13, 16, 25, 19, 20, 12, 10, 20, 24, 21, 12, 23, 21, 24, 22, 17, 23,
#        13, 13, 21, 13, 11, 10, 22, 13, 11, 17,  8, 11, 15, 18, 10, 22, 19,
#        17, 21, 14, 18, 15, 19, 15, 12, 20, 24, 10, 10,  8, 10, 19, 20, 20,
#        24, 21, 15, 18, 17, 13, 21, 10, 13, 21,  8, 10, 14, 14, 16, 13, 19,
#        17, 19, 22, 14, 10, 18, 23, 21, 21, 13, 14, 14, 14, 11, 21, 10, 20,
#         9, 12,  8, 11, 15, 19,  9, 14, 13, 12, 13, 16, 21, 20, 21, 12, 18,
#        14, 19, 24, 11,  8, 19, 21, 19, 20,  9, 11, 20, 14, 20, 19, 10, 12,
#        11, 21, 20, 21, 19, 11, 10, 17, 19, 25, 21, 20, 21, 25, 15, 18, 17,
#        21, 21, 25, 14, 22, 21, 21, 12, 21, 15, 19, 19, 11, 17, 20, 16, 13,
#        20, 12, 18, 19, 15,  9, 21, 23, 20, 24, 24, 14, 18, 20,  8, 23, 14,
#        20, 12, 17, 15, 23, 13, 18, 13,  8, 15,  9,  9, 10, 15, 14,  8, 12,
#        20, 16, 12, 20, 14, 20, 14, 19, 14, 18, 11, 18, 17, 15, 23, 14, 10,
#        11, 10, 20, 14, 19, 23, 22, 21, 21, 23, 13, 11, 17, 11, 19, 25, 10,
#        12,  8,  8, 17, 22, 15, 15, 15, 12, 15, 20,  8, 21, 15,  8, 15, 12,
#        23, 13, 18, 24, 13, 18, 13, 11, 21, 23, 25, 20, 20, 14, 21, 14, 15,
#        13, 13,  9,  9, 19, 13, 15, 11, 22, 13, 19, 20, 10, 11, 17, 14, 22,
#        17, 21, 20,  9, 11, 14, 17, 14, 22, 18, 10, 12, 20,  9, 19, 14, 17,
#        17, 23, 23, 19, 22, 25, 21, 18, 12, 23, 19, 14, 19, 12])

# %%
Y_pred1
# Out:
# array([[12.481866 ],
#        [18.24147  ],
#        [25.625465 ],
#        [17.910988 ],
#        [20.449291 ],
#        [17.100315 ],
#        [ 9.981087 ],
#        [19.613373 ],
#        [23.848675 ],
#        [19.96504  ],
#        [12.197672 ],
#        [20.45086  ],
#        [20.60511  ],
#        [27.95697  ],
#        [22.370975 ],
#        [16.514418 ],
#        [23.367958 ],
#        [15.567169 ],
#        [12.718833 ],
#        [22.317337 ],
#        [16.825258 ],
#        [ 8.275408 ],
#        [11.058921 ],
#        [21.730427 ],
#        [12.511995 ],
#        [12.355771 ],
#        [17.938736 ],
#        [ 8.532982 ],
#        [12.79523  ],
#        [15.261434 ],
#        [21.20642  ],
#        [10.921072 ],
#        [22.654818 ],
#        [18.060272 ],
#        [13.189887 ],
#        [20.061234 ],
#        [13.042773 ],
#        [19.190613 ],
#        [17.825514 ],
#        [21.17643  ],
#        [16.945368 ],
#        [11.568986 ],
#        [20.581537 ],
#        [23.010422 ],
#        [11.387443 ],
#        [11.666881 ],
#        [13.385867 ],
#        [11.609836 ],
#        [17.504913 ],
#        [17.13632  ],
#        [20.938576 ],
#        [21.355835 ],
#        [20.625433 ],
#        [15.49464  ],
#        [16.00012  ],
#        [16.853706 ],
#        [15.2898035],
#        [21.544506 ],
#        [12.753645 ],
#        [19.55127  ],
#        [17.882763 ],
#        [13.658132 ],
#        [10.91147  ],
#        [12.483811 ],
#        [13.427656 ],
#        [17.843004 ],
#        [13.827725 ],
#        [20.82961  ],
#        [18.419825 ],
#        [19.637096 ],
#        [20.932758 ],
#        [20.84246  ],
#        [19.038094 ],
#        [12.419778 ],
#        [10.92238  ],
#        [16.853271 ],
#        [11.109123 ],
#        [18.001238 ],
#        [24.205368 ],
#        [10.386124 ],
#        [11.716022 ],
#        [ 8.949338 ],
#        [13.512049 ],
#        [16.330807 ],
#        [20.92614  ],
#        [13.820144 ],
#        [14.455291 ],
#        [17.778091 ],
#        [12.794202 ],
#        [10.60926  ],
#        [21.246502 ],
#        [10.627902 ],
#        [20.569195 ],
#        [13.318157 ],
#        [ 8.860932 ],
#        [15.084401 ],
#        [13.755294 ],
#        [25.9942   ],
#        [14.391334 ],
#        [19.733173 ],
#        [27.462135 ],
#        [18.457253 ],
#        [18.854086 ],
#        [14.317448 ],
#        [10.6629   ],
#        [21.077879 ],
#        [23.023235 ],
#        [25.350853 ],
#        [20.166225 ],
#        [18.72747  ],
#        [11.919705 ],
#        [22.203892 ],
#        [13.719669 ],
#        [14.92147  ],
#        [14.394837 ],
#        [10.198777 ],
#        [13.594315 ],
#        [11.677224 ],
#        [17.428167 ],
#        [15.220994 ],
#        [13.253331 ],
#        [12.337421 ],
#        [21.876825 ],
#        [10.667378 ],
#        [19.185978 ],
#        [18.285267 ],
#        [10.252529 ],
#        [10.834906 ],
#        [14.825744 ],
#        [14.403203 ],
#        [20.939873 ],
#        [18.183006 ],
#        [18.704533 ],
#        [22.216385 ],
#        [13.582223 ],
#        [12.400563 ],
#        [12.792205 ],
#        [19.176163 ],
#        [15.879922 ],
#        [19.824657 ],
#        [19.89523  ],
#        [10.145871 ],
#        [17.051197 ],
#        [23.39545  ],
#        [ 9.419442 ],
#        [19.285936 ],
#        [11.173104 ],
#        [14.97885  ],
#        [17.059952 ],
#        [26.290924 ],
#        [23.085804 ],
#        [18.083542 ],
#        [23.53839  ],
#        [21.63979  ],
#        [21.528545 ],
#        [15.787578 ],
#        [10.9462595],
#        [23.191181 ],
#        [18.092064 ],
#        [12.7519045],
#        [20.665047 ],
#        [11.15958  ]], dtype=float32)

# %% [markdown]
# # DNNR Model Optimisation

# %% [markdown]
# ### Data scaling

# %%
# apply data standardisation

from sklearn.preprocessing import StandardScaler

TargetVariable =['ACTScore']
Predictors =['Location', 'Age', 'Gender', 'Humidity', 'Pressure', 'Temperature', 'UVIndex', 'WindSpeed', 'OutdoorJob', 'OutdoorActivities']

X = data[Predictors].values
Y = data[TargetVariable].values

PredictorScaler = StandardScaler()
TargetVarScaler = StandardScaler()

# store the fit object for later reference
PredictorScalerFit = PredictorScaler.fit(X)
TargetVarScalerFit = TargetVarScaler.fit(Y)

# generate the standardised values of X and Y
X = PredictorScalerFit.transform(X)
Y = TargetVarScalerFit.transform(Y)

# split Train and Test 
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.30, random_state=42)

# check the shapes of training and testing datasets
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (707, 10)
# (707, 1)
# (303, 10)
# (303, 1)

# %% [markdown]
# ### Optimisation algorithm

# %% [markdown]
# #### Hidden layers and hidden nodes

# %%
# from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from scikeras.wrappers import KerasRegressor
from sklearn.model_selection import GridSearchCV
    
def FindLayerNodes(n_layers, n_layer_nodes):
    layers = []
    nodes = n_layer_nodes
    return layers

def createmodel(n_layers, n_layer_nodes):
    model = Sequential()
    n_nodes = FindLayerNodes(n_layers, n_layer_nodes)
    for i in range(1, n_layers):
        if i==1:
            model.add(Dense(n_layer_nodes, input_dim=10, activation='relu'))
        else:
            model.add(Dense(n_nodes[i], activation='relu'))
            
    model.add(Dense(1,))
    model.compile(optimizer='adam', loss='mean_squared_error')
    
    return model

model =  KerasRegressor(build_fn=createmodel, verbose=0)

# %%
import time

# starting time
start = time.time()

# find the optimum number of hidden layers and hidden nodes
param_grid1 = dict(n_layers=[2, 3, 4], n_layer_nodes = [10, 20, 30, 50])
grid1 = GridSearchCV(estimator = model, param_grid = param_grid1)
grid1.fit(X,Y)

# summarise results
print('Best score: %s' % grid1.best_score_)
print('Best parameters: %s' % grid1.best_params_)

# calculate time
end = time.time()
print(f'Total time taken: {end - start}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[118], line 9
#       7 param_grid1 = dict(n_layers=[2, 3, 4], n_layer_nodes = [10, 20, 30, 50])
#       8 grid1 = GridSearchCV(estimator = model, param_grid = param_grid1)
# ----> 9 grid1.fit(X,Y)
#      11 # summarise results
#      12 print('Best score: %s' % grid1.best_score_)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/sklearn/model_selection/_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1422, in GridSearchCV._run_search(self, evaluate_candidates)
#    1420 def _run_search(self, evaluate_candidates):
#    1421     """Search all candidates in param_grid"""
# -> 1422     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/sklearn/model_selection/_search.py:845, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     837 if self.verbose > 0:
#     838     print(
#     839         "Fitting {0} folds for each of {1} candidates,"
#     840         " totalling {2} fits".format(
#     841             n_splits, n_candidates, n_candidates * n_splits
#     842         )
#     843     )
# --> 845 out = parallel(
#     846     delayed(_fit_and_score)(
#     847         clone(base_estimator),
#     848         X,
#     849         y,
#     850         train=train,
#     851         test=test,
#     852         parameters=parameters,
#     853         split_progress=(split_idx, n_splits),
#     854         candidate_progress=(cand_idx, n_candidates),
#     855         **fit_and_score_kwargs,
#     856     )
#     857     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     858         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     859     )
#     860 )
#     862 if len(out) < 1:
#     863     raise ValueError(
#     864         "No fits were performed. "
#     865         "Was the CV iterator empty? "
#     866         "Were there no candidates?"
#     867     )
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/sklearn/utils/parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/joblib/parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/joblib/parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/sklearn/utils/parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:717, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     710 fit_params = _check_fit_params(X, fit_params, train)
#     712 if parameters is not None:
#     713     # here we clone the parameters, since sometimes the parameters
#     714     # themselves might be estimators, e.g. when we search over different
#     715     # estimators in a pipeline.
#     716     # ref: https://github.com/scikit-learn/scikit-learn/pull/26786
# --> 717     estimator = estimator.set_params(**clone(parameters, safe=False))
#     719 start_time = time.time()
#     721 X_train, y_train = _safe_split(estimator, X, y, train)
#
# File ~/Desktop/BreatheEasy/virtualenv/lib/python3.11/site-packages/scikeras/wrappers.py:1165, in BaseWrapper.set_params(self, **params)
#    1161             super().set_params(**{param: value})
#    1162         except ValueError:
#    1163             # Give a SciKeras specific user message to aid
#    1164             # in moving from the Keras wrappers
# -> 1165             raise ValueError(
#    1166                 f"Invalid parameter {param} for estimator {self.__name__}."
#    1167                 "\nThis issue can likely be resolved by setting this parameter"
#    1168                 f" in the {self.__name__} constructor:"
#    1169                 f"\n`{self.__name__}({param}={value})`"
#    1170                 "\nCheck the list of available parameters with"
#    1171                 " `estimator.get_params().keys()`"
#    1172             ) from None
#    1173 return self
#
# ValueError: Invalid parameter n_layer_nodes for estimator KerasRegressor.
# This issue can likely be resolved by setting this parameter in the KerasRegressor constructor:
# `KerasRegressor(n_layer_nodes=10)`
# Check the list of available parameters with `estimator.get_params().keys()`

# %% [markdown]
# #### Bach size and epochs

# %%
# starting time
start = time.time()

# find the optimum bacth size
param_grid2 = dict(n_layers=[2], n_layer_nodes = [50], batch_size = [10,20])
grid2 = GridSearchCV(estimator = model, param_grid = param_grid2)
grid2.fit(X,Y)

# summarise results
print('Best score: %s' % grid2.best_score_)
print('Best parameters: %s' % grid2.best_params_)

# calculate time
end = time.time()
print(f'Total time taken: {end - start}')
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# starting time
start = time.time()

# find the optimum number of epochs
param_grid2 = dict(n_layers=[2], n_layer_nodes = [50], batch_size = [10], epochs = [100,200])
grid2 = GridSearchCV(estimator = model, param_grid = param_grid2)
grid2.fit(X,Y)

# summarise results
print('Best score: %s' % grid2.best_score_)
print('Best parameters: %s' % grid2.best_params_)

# calculate time
end = time.time()
print(f'Total time taken: {end - start}')
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# #### Optimiser

# %%
# starting time
start = time.time()

# find the optimiser
from sklearn.metrics import make_scorer

def make_regression_dnnr(Optimizer_trial):
        
    model = Sequential()
    model.add(Dense(units=50, input_dim=10, activation='relu'))
    model.add(Dense(units=50, activation='relu'))
    model.add(Dense(1,))
    model.compile(loss='mean_squared_error', optimizer=Optimizer_trial)
    return model

param_grid3 = {'Optimizer_trial':['sgd', 'adam', 'rmsprop']}

model = KerasRegressor(make_regression_dnnr, verbose=False)

# create the GridSearchCV
grid3 = GridSearchCV(estimator=model, param_grid = param_grid3)

# apply GridSearchCV for paramenters
grid3.fit(X,Y, verbose=0)

# summarise results
print('Best score: %s' % grid3.best_score_)
print('Best optimiser: %s' % grid3.best_params_)

# calculate time
end = time.time()
print(f'Total time taken: {end - start}')
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# #### Loss function

# %%
# starting time
start = time.time()

# find the loss function 
from sklearn.metrics import make_scorer

def make_regression_dnnr(Loss_function):
        
    model = Sequential()
    model.add(Dense(units=50, input_dim=10, activation='relu'))
    model.add(Dense(units=50, activation='relu'))
    model.add(Dense(1,))
    model.compile(loss=Loss_function, optimizer='adam')
    return model

param_grid4 = {'Loss_function':['mae', 'mse', 'mape']}

model = KerasRegressor(make_regression_dnnr, verbose=False)

# create the GridSearchCV
grid4 = GridSearchCV(estimator=model, param_grid = param_grid4)

# apply GridSearchCV for paramenters
grid4.fit(X,Y, verbose=0)

# summarise results
print('Best score: %s' % grid4.best_score_)
print('Best loss function: %s' % grid4.best_params_)

# calculate time
end = time.time()
print(f'Total time taken: {end - start}')
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# #### Weight initialiser

# %%
# starting time
start = time.time()

# find the optimum weight initialiser
def create_model(init_mode):
    # create model
    model = Sequential()
    model.add(Dense(50, input_dim=10, kernel_initializer=init_mode, activation='relu'))
    model.add(Dense(50, kernel_initializer=init_mode, activation='relu'))
    model.add(Dense(1, kernel_initializer=init_mode))
    # Compile model
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# create model
model = KerasRegressor(build_fn=create_model, epochs=100, batch_size=10, verbose=0)

# define the grid search parameters
init_mode = ['uniform', 'normal']
param_grid5 = dict(init_mode=init_mode)
grid5 = GridSearchCV(estimator=model, param_grid =param_grid5)
grid5.fit(X, Y)

# summarise results
print('Best score: %s' % grid5.best_score_)
print('Best initialiser: %s' % grid5.best_params_)

# calculate time
end = time.time()
print(f'Total time taken: {end - start}')
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# # Optimised DNNR

# %%
# define the optimised model

model2 = Sequential()

model2.add(Dense(units=50, input_dim=10, kernel_initializer='normal', activation='relu'))
model2.add(Dense(units=50, kernel_initializer='normal', activation='relu'))

model2.add(Dense(1, kernel_initializer='normal'))
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# apply optimiser

model2.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# starting time
import time
start = time.time()

model2.fit(x=X_train,y=Y_train,
          validation_data=(X_test,Y_test),
          batch_size=10,epochs=100)

# calculate time
end = time.time()
print(f'Total time taken: {end - start}')
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
model2.summary()
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
loss_df = pd.DataFrame(model2.history.history)
loss_df.plot(figsize=(12,8))
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
Y_pred2 = model2.predict(X_test)
X_test
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# evaluation metrics
# explained variance score: best possible score is 1 and lower values are worse
from sklearn import metrics

print('Mean Absolute Error: {:.2f}'.format(metrics.mean_absolute_error(Y_test, Y_pred2)))
print('Mean Squared Error: {:.2f}'.format(metrics.mean_squared_error(Y_test, Y_pred2)))
print('Explained Variance Score: {:.2f}'.format(metrics.explained_variance_score(Y_test,Y_pred2)))
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# show prediction result
fig3 = plt.figure(figsize = (10,5))
plt.scatter(Y_test,Y_pred2)
plt.plot(Y_test,Y_test,'r')
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# show residuals
fig4 = plt.figure(figsize = (10,5))
residuals2 = (Y_test - Y_pred2)
sns.distplot(residuals2)
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# generate predictions on testing set
Predictions = model2.predict(X_test)
 
# scale the predicted ACTScore back to original ACTScore scale
Predictions = TargetVarScalerFit.inverse_transform(Predictions)
 
# scale the Y_test ACTScore data back to original ACTScore scale
Y_test_orig = TargetVarScalerFit.inverse_transform(Y_test)
 
# scale the test data back to original scale
Test_Data = PredictorScalerFit.inverse_transform(X_test)
 
TestingData = pd.DataFrame(data = Test_Data, columns = Predictors)
TestingData['ACTScore'] = Y_test_orig
TestingData['PredictedACTScore'] = Predictions
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# compute the total accuracy from absolute error
Absolute_Error = 100 * (abs(TestingData['ACTScore'] - TestingData['PredictedACTScore']) / TestingData['ACTScore'])
TestingData['APE'] = Absolute_Error

print('The Accuracy of the optimised DNNR model is:', 100-np.mean(Absolute_Error))
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# compare the prediction with real ACTScore for the first column
ACT_prediction = data['ACTScore'][0]

print ("Original ACT Score = 14")
print ("Predicted ACT Score =", ACT_prediction)
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
# Out:
# Running cells with 'Python 3.11.6 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/opt/homebrew/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
